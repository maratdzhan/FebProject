# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
###################################################################
###################### LOOKING FOR MAXIMUM KQ #####################
###################################################################

# %%
kq=pd.read_csv('~D:/Vasiliev/Python/Jupyter/feb/2/z9-1_nom.csv')

# %%
iv=kq.head(163)
print(iv.iloc[28])
# Out:
# kq    1.169
# Name: 28, dtype: float64

# %%
###################################################################
########## SAMPLES FOR 29 FA. CONTRACTION AND UNCLAPSING ##########
############       AT 8(18)  AND  9(29) CYCLES         ############
###################################################################

# %%
#####################
### NOMINAL STATE ###
#####################

# %%
#kk_n8_=pd.read_csv('~D:/Vasiliev/PERMAK-A/nv/8nom_9dev/out_kk_0.csv',sep=';')
kk_n9=pd.read_csv('~D:/Vasiliev/Python/Jupyter/feb/3/y9-8n-9n.csv',sep=';')
indexes=np.arange(0,26,step=1)
etvs_8=17
etvs_9=29

# %%
rn1=kk_n9.query('tvs==@etvs_9 & tvel==276')
rn1.index=indexes
rn2=kk_n9.query('tvs==@etvs_9 & tvel==286')
rn2.index=indexes
rn3=kk_n9.query('tvs==@etvs_9 & tvel==296')
rn3.index=indexes
rn4=kk_n9.query('tvs==@etvs_9 & tvel==306')
rn4.index=indexes
rn5=kk_n9.query('tvs==@etvs_9 & tvel==316')
rn5.index=indexes
rn6=kk_n9.query('tvs==@etvs_9 & tvel==326')
rn6.index=indexes
plt.figure(figsize=(15,7))
plt.grid(True)
plt.plot(indexes,rn1.loc[:,'kk'])
plt.plot(indexes,rn2.loc[:,'kk'])
plt.plot(indexes,rn3.loc[:,'kk'])
plt.plot(indexes,rn4.loc[:,'kk'])
plt.plot(indexes,rn5.loc[:,'kk'])
plt.plot(indexes,rn6.loc[:,'kk'])
plt.legend(['1','2','3','4','5','6'])

# %%
#########################
### CONTRACTION STATE ###
#########################

# %%
#kk_c8_=pd.read_csv('~D:/Vasiliev/PERMAK-A/nv/8nom_9dev/out_kk_0.csv',sep=';')
kk_c9=pd.read_csv('~D:/Vasiliev/Python/Jupyter/feb/3/y9-8u-9c.csv',sep=';')
indexes=np.arange(0,26,step=1)
etvs_8=17
etvs_9=29

# %%
rc1=kk_c9.query('tvs==@etvs_9 & tvel==276')
rc1.index=indexes
rc2=kk_c9.query('tvs==@etvs_9 & tvel==286')
rc2.index=indexes
rc3=kk_c9.query('tvs==@etvs_9 & tvel==296')
rc3.index=indexes
rc4=kk_c9.query('tvs==@etvs_9 & tvel==306')
rc4.index=indexes
rc5=kk_c9.query('tvs==@etvs_9 & tvel==316')
rc5.index=indexes
rc6=kk_c9.query('tvs==@etvs_9 & tvel==326')
rc6.index=indexes
plt.figure(figsize=(15,7))
plt.grid(True)
plt.plot(indexes,rc1.loc[:,'kk'])
plt.plot(indexes,rc2.loc[:,'kk'])
plt.plot(indexes,rc3.loc[:,'kk'])
plt.plot(indexes,rc4.loc[:,'kk'])
plt.plot(indexes,rc5.loc[:,'kk'])
plt.plot(indexes,rc6.loc[:,'kk'])
plt.legend(['1','2','3','4','5','6'])

# %%
#########################
### UNCPLASING  STATE ###
#########################

# %%
kk_u9=pd.read_csv('~D:/Vasiliev/Python/Jupyter/feb/3/y9-8c-9u.csv',sep=';')
indexes=np.arange(0,26,step=1)
etvs_8=17
etvs_9=29

# %%
ru1=kk_u9.query('tvs==@etvs_9 & tvel==276')
ru1.index=indexes
ru2=kk_u9.query('tvs==@etvs_9 & tvel==286')
ru2.index=indexes
ru3=kk_u9.query('tvs==@etvs_9 & tvel==296')
ru3.index=indexes
ru4=kk_u9.query('tvs==@etvs_9 & tvel==306')
ru4.index=indexes
ru5=kk_u9.query('tvs==@etvs_9 & tvel==316')
ru5.index=indexes
ru6=kk_u9.query('tvs==@etvs_9 & tvel==326')
ru6.index=indexes
plt.figure(figsize=(15,7))
plt.grid(True)
plt.plot(indexes,ru1.loc[:,'kk'])
plt.plot(indexes,ru2.loc[:,'kk'])
plt.plot(indexes,ru3.loc[:,'kk'])
plt.plot(indexes,ru4.loc[:,'kk'])
plt.plot(indexes,ru5.loc[:,'kk'])
plt.plot(indexes,ru6.loc[:,'kk'])
plt.legend(['1','2','3','4','5','6'])

# %%
plt.figure(figsize=(15,7))
plt.grid(True)
plt.plot(indexes,rn1.loc[:,'kk'])
plt.plot(indexes,rc1.loc[:,'kk'])
plt.plot(indexes,ru1.loc[:,'kk'])
plt.legend(['nominal','contraction','unclapsing'])
plt.show()
#############################################
###############  SECOND-YEAR  ###############
#############################################

# %%
plt.figure(figsize=(15,7))
plt.grid(True)
plt.plot(indexes,rn2.loc[:,'kk'])
plt.plot(indexes,rc2.loc[:,'kk'])
plt.plot(indexes,ru2.loc[:,'kk'])
plt.legend(['nominal','contraction','unclapsing'])
plt.show()
##############################################
############## HALF-SECOND-YEAR ##############
##############################################

# %%
plt.figure(figsize=(15,7))
plt.grid(True)
plt.plot(indexes,rn3.loc[:,'kk'])
plt.plot(indexes,rc3.loc[:,'kk'])
plt.plot(indexes,ru3.loc[:,'kk'])
plt.legend(['nominal','contraction','unclapsing'])
plt.show()
#############################################
################  ZERO-YEAR  ################
#############################################

# %%
plt.figure(figsize=(15,7))
plt.grid(True)
plt.plot(indexes,rn4.loc[:,'kk'])
plt.plot(indexes,rc4.loc[:,'kk'])
plt.plot(indexes,ru4.loc[:,'kk'])
plt.legend(['nominal','contraction','unclapsing'])
plt.show()
##############################################
############## HALF-SECOND-YEAR ##############
##############################################

# %%
plt.figure(figsize=(15,7))
plt.grid(True)
plt.plot(indexes,rn5.loc[:,'kk'])
plt.plot(indexes,rc5.loc[:,'kk'])
plt.plot(indexes,ru5.loc[:,'kk'])
plt.legend(['nominal','contraction','unclapsing'])
plt.show()
#############################################
###############  SECOND-YEAR  ###############
#############################################

# %%
plt.figure(figsize=(15,7))
plt.grid(True)
plt.plot(indexes,rn6.loc[:,'kk'])
plt.plot(indexes,rc6.loc[:,'kk'])
plt.plot(indexes,ru6.loc[:,'kk'])
plt.legend(['nominal','contraction','unclapsing'])
plt.show()
#############################################
#############  TWO-THIRDS-YEAR  #############
#############################################

# %%
t1=pd.read_csv('~D:/Vasiliev/Python/Jupyter/feb/3/y9-8n-9u.csv',sep=';')
t2=pd.read_csv('~D:/Vasiliev/Python/Jupyter/feb/3/y9-8c-9u.csv',sep=';')
y1=pd.read_csv('~D:/Vasiliev/Python/Jupyter/feb/3/y9-8n-9c.csv',sep=';')
y2=pd.read_csv('~D:/Vasiliev/Python/Jupyter/feb/3/y9-8u-9c.csv',sep=';')
ectvs=29
ectvel=276

# %%
u1=t1.query('tvs==@ectvs & tvel==@ectvel')
u2=t2.query('tvs==@ectvs & tvel==@ectvel')
i1=y1.query('tvs==@ectvs & tvel==@ectvel')
i2=y2.query('tvs==@ectvs & tvel==@ectvel')

# %%
plt.figure(figsize=(15,10))
plt.grid(True)

u1.index=np.arange(0,26,step=1)

u2.index=np.arange(0,26,step=1)

i1.index=np.arange(0,26,step=1)
i2.index=np.arange(0,26,step=1)
plt.plot(u1.loc[:,'kk'],'r--')
plt.plot(u2.loc[:,'kk'],'b--')
plt.plot(i1.loc[:,'kk'],'g-x')
plt.plot(i2.loc[:,'kk'],'m-x')
plt.plot(rn1.loc[:,'kk'],'r-o')
plt.legend(['8 nominal, 9 unclapsed','8 contracted, 9 unclapsed','8 nominal, 9 contracted','8 unclapsed, 9 contracted'],fontsize=20)
plt.title('kk deviation for FA#29 rod#277 during 9th cycle',fontsize=20)
plt.xlabel('time',fontsize=16)
plt.ylabel('KK',fontsize=16)
plt.show()

# %%
# Out:
#         tvs  tvel  time      kk
# 248144   29   276     0  0.9498
# 248145   29   276     1  0.9473
# 248146   29   276     2  0.9464
# 248147   29   276     3  0.9485
# 248148   29   276     4  0.9522
# 248149   29   276     5  0.9561
# 248150   29   276     6  0.9601
# 248151   29   276     7  0.9640
# 248152   29   276     8  0.9680
# 248153   29   276     9  0.9713
# 248154   29   276    10  0.9749
# 248155   29   276    11  0.9777
# 248156   29   276    12  0.9797
# 248157   29   276    13  0.9804
# 248158   29   276    14  0.9810
# 248159   29   276    15  0.9863
# 248160   29   276    16  0.9955
# 248161   29   276    17  1.0063
# 248162   29   276    18  1.0124
# 248163   29   276    19  1.0154
# 248164   29   276    20  1.0133
# 248165   29   276    21  1.0086
# 248166   29   276    22  1.0027
# 248167   29   276    23  0.9986
# 248168   29   276    24  0.9939
# 248169   29   276    25  0.9903
